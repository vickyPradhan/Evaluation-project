# %% [markdown]
# # Global Power plant Project:-

# %% [markdown]
# # problem statement:-

# %% [markdown]
# The Global Power Plant Database is a comprehensive, open source database of power plants around the world. It centralizes power plant data to make it easier to navigate, compare and draw insights for one’s own analysis. The database covers approximately 35,000 power plants from 167 countries and includes thermal plants (e.g. coal, gas, oil, nuclear, biomass, waste, geothermal) and renewables (e.g. hydro, wind, solar). Each power plant is geolocated and entries contain information on plant capacity, generation, ownership, and fuel type. It will be continuously updated as data becomes available.

# %% [markdown]
# We define the "Fuel Type" attribute of our database based on common fuel categories.
#
# Prediction :   Make two prediction :-
# 1) Primary Fuel
# 2) capacity_mw

# %% [markdown]
# Import all the required library.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # importing DataSet:-

# %%
df=pd.read_csv('https://raw.githubusercontent.com/wri/global-power-plant-database/master/source_databases_csv/database_IND.csv')

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %%
df.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %% [markdown]
# # Data inspection & descriptions:-

# %% [raw]
# The database includes the following indicators:
#
# -`country` (text): 3 character country code corresponding to the ISO 3166-1 alpha-3 specification [5]
#
# -`country_long` (text): longer form of the country designation
#
# -`name` (text): name or title of the power plant, generally in Romanized form
#
# -`gppd_idnr` (text): 10 or 12 character identifier for the power plant
#
# -`capacity_mw` (number): electrical generating capacity in megawatts
#
# -`latitude` (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
#
# -`longitude` (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
#
# -`primary_fuel` (text): energy source used in primary electricity generation or export
#
# -`other_fuel1` (text): energy source used in electricity generation or export
#
# -`other_fuel2` (text): energy source used in electricity generation or export
#
# -`other_fuel3` (text): energy source used in electricity generation or export
#
# -`commissioning_year` (number): year of plant operation, weighted by unit-capacity when data is available
#
# -`owner` (text): majority shareholder of the power plant, generally in Romanized form
#
# -`source` (text): entity reporting the data; could be an organization, report, or document, generally in Romanized form
#
# -`url` (text): web document corresponding to the `source` field
#
# -`geolocation_source` (text): attribution for geolocation information
#
# -`wepp_id` (text): a reference to a unique plant identifier in the widely-used PLATTS-WEPP database.
#
# -`year_of_capacity_data` (number): year the capacity information was reported
#
# -`generation_gwh_2013` (number): electricity generation in gigawatt-hours reported for the year 2013
#
# -`generation_gwh_2014` (number): electricity generation in gigawatt-hours reported for the year 2014
#
# -`generation_gwh_2015` (number): electricity generation in gigawatt-hours reported for the year 2015
#
# -`generation_gwh_2016` (number): electricity generation in gigawatt-hours reported for the year 2016
#
# -`generation_gwh_2017` (number): electricity generation in gigawatt-hours reported for the year 2017
#
# -`generation_gwh_2018` (number): electricity generation in gigawatt-hours reported for the year 2018
#
# -`generation_gwh_2019` (number): electricity generation in gigawatt-hours reported for the year 2019
#
# -`generation_data_source` (text): attribution for the reported generation information
#
# -`estimated_generation_gwh_2013` (number): estimated electricity generation in gigawatt-hours for the year 2013
#
# -`estimated_generation_gwh_2014` (number): estimated electricity generation in gigawatt-hours for the year 2014
#
# -`estimated_generation_gwh_2015` (number): estimated electricity generation in gigawatt-hours for the year 2015
#
# -`estimated_generation_gwh_2016` (number): estimated electricity generation in gigawatt-hours for the year 2016
#
# -`estimated_generation_gwh_2017` (number): estimated electricity generation in gigawatt-hours for the year 2017
#
# -'estimated_generation_note_2013` (text): label of the model/method used to estimate generation for the year 2013
#
# -`estimated_generation_note_2014` (text): label of the model/method used to estimate generation for the year 2014
#
# -`estimated_generation_note_2015` (text): label of the model/method used to estimate generation for the year 2015
#
# -`estimated_generation_note_2016` (text): label of the model/method used to estimate generation for the year 2016
#
# -`estimated_generation_note_2017` (text): label of the model/method used to estimate generation for the year 2017

# %%
df.shape
# Out:
# (907, 27)

# %%
print('This dataset has {} observations with {} features.'.format(df.shape[0], df.shape[1]))
# Out:
# This dataset has 907 observations with 27 features.

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %% [markdown]
# # EDA:-

# %%
df.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                 object
# other_fuel1                  object
# other_fuel2                  object
# other_fuel3                 float64
# commissioning_year          float64
# owner                        object
# source                       object
# url                          object
# geolocation_source           object
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_gwh_2018         float64
# generation_gwh_2019         float64
# generation_data_source       object
# ...

# %% [markdown]
# We can see the Dataset contains object and float type of data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %% [raw]
# As we can see
# -Data having 908 columns and 25 Rows
# -Out of 25, 13 columns are float data type and 12 columns are Oject data type
# -There are some null values present in some solumns.
# -other_fuel3,wepp_id,generation_gwh_2013,generation_gwh_2019 and estimated_generation_gwh has all Nan values so i can drop these columns.
# -other_fuel2 has only one non null value which means all other values are NaN so this column also has nothing to do with my data training.

# %%
#all those columns are full of null values soo we just drop those columns
df=df.drop(["other_fuel3"],axis=1)
df=df.drop(["wepp_id"],axis=1)
df=df.drop(["generation_gwh_2013"],axis=1)
df=df.drop(["generation_gwh_2019"],axis=1)
df=df.drop(["estimated_generation_gwh"],axis=1)
df=df.drop(["other_fuel2"],axis=1)

# %%
#Checking unique values
df.nunique()
# Out:
# country                     1
# country_long                1
# name                      907
# gppd_idnr                 907
# capacity_mw               361
# latitude                  836
# longitude                 827
# primary_fuel                8
# other_fuel1                 3
# commissioning_year         73
# owner                     280
# source                    191
# url                       304
# geolocation_source          3
# year_of_capacity_data       1
# generation_gwh_2014       371
# generation_gwh_2015       396
# generation_gwh_2016       403
# generation_gwh_2017       408
# generation_gwh_2018       410
# generation_data_source      1
# dtype: int64

# %% [raw]
# As we can see,
# -These are the number of unique values present in each columns.
# -country, country_long, year_of_capacity_data and generation_data_source has only one unique count which means all the values of the column are filled with NaN values so no need to keep those columns.

# %%
df=df.drop(["country"],axis=1)
df=df.drop(["country_long"],axis=1)
df=df.drop(["year_of_capacity_data"],axis=1)
df=df.drop(["generation_data_source"],axis=1)

# %%
df.shape
# Out:
# (907, 17)

# %% [markdown]
# previously it was 27 columns and now it has 17 columns present after the drop of unneccesary columns.

# %%
df.nunique()
# Out:
# name                   907
# gppd_idnr              907
# capacity_mw            361
# latitude               836
# longitude              827
# primary_fuel             8
# other_fuel1              3
# commissioning_year      73
# owner                  280
# source                 191
# url                    304
# geolocation_source       3
# generation_gwh_2014    371
# generation_gwh_2015    396
# generation_gwh_2016    403
# generation_gwh_2017    408
# generation_gwh_2018    410
# dtype: int64

# %%
for i in df.columns:
        print(df[i].value_counts())
        print('***********')
# Out:
# ACME Solar Tower           1
# RAICHUR                    1
# PRYAGRAJ (BARA) TPP        1
# PULICHINTALA               1
# PUNE MILL                  1
#                           ..
# KADANA                     1
# KADRA                      1
# KAHALGAON                  1
# KAIGA                      1
# iEnergy Theni Wind Farm    1
# Name: name, Length: 907, dtype: int64
# ***********
# WRI1020239    1
# IND0000356    1
# IND0000346    1
# IND0000523    1
# WRI1019978    1
#              ..
# IND0000167    1
# IND0000168    1
# IND0000169    1
# IND0000170    1
# WRI1026761    1
# Name: gppd_idnr, Length: 907, dtype: int64
# ***********
# 5.0       39
# 10.0      22
# 600.0     20
# 15.0      20
# 1200.0    19
#           ..
# 291.0      1
# 645.0      1
# 41.4       1
# 17.5       1
# 106.6      1
# Name: capacity_mw, Length: 361, dtype: int64
# ***********
# 19.0004    3
# 24.1917    3
# 24.8747    2
# 13.2450    2
# 11.5336    2
#           ..
# 22.7554    1
# 27.1598    1
# ...

# %% [raw]
# From above observation se can see:-
#     -Name & gppd_idnr columns has unique names for each power plant so we can drop this column.
#     -Owner also looks like an unnecessary column since keeping all owner names will never  give inputs to my prediction so      i think i have to drop this column.
#     -And url column also has no input for prediction ao i can drop this column as well.

# %%
#delete columns from above observation
df=df.drop(["name"],axis=1)
df=df.drop(["gppd_idnr"],axis=1)
df=df.drop(["url"],axis=1)
df=df.drop(["owner"],axis=1)

# %%
df.shape
# Out:
# (907, 13)

# %% [markdown]
# we can see the column shape is decresing 27 to 13 after deleting unneccesary columns

# %% [markdown]
# # Checking Null values in the DataFrame:-

# %%
df.isnull().sum()
# Out:
# capacity_mw              0
# latitude                46
# longitude               46
# primary_fuel             0
# other_fuel1            709
# commissioning_year     380
# source                   0
# geolocation_source      19
# generation_gwh_2014    509
# generation_gwh_2015    485
# generation_gwh_2016    473
# generation_gwh_2017    467
# generation_gwh_2018    459
# dtype: int64

# %% [markdown]
# as we can see there aare lots of null values are present in this dataset,except capacity_mw, primary_fuel and source.

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# From above observation we can clearly see there is many null values are present.

# %%
df.skew()
# Out:
# capacity_mw            3.123576
# latitude              -0.145866
# longitude              1.112646
# commissioning_year    -1.067949
# generation_gwh_2014    3.342707
# generation_gwh_2015    3.665904
# generation_gwh_2016    3.512370
# generation_gwh_2017    3.566070
# generation_gwh_2018    3.476298
# dtype: float64

# %%
df.head()
# Out:
#    capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0          2.5   28.1839    73.2407        Solar         NaN
# 1         98.0   24.7663    74.6090         Coal         NaN
# 2         39.2   21.9038    69.3732         Wind         NaN
# 3        135.0   23.8712    91.3602          Gas         NaN
# 4       1800.0   21.9603    82.4091         Coal         Oil
#
#    commissioning_year                                source  \
# 0              2011.0  National Renewable Energy Laboratory
# 1                 NaN                  Ultratech Cement ltd
# 2                 NaN                                   CDM
# 3              2004.0         Central Electricity Authority
# 4              2015.0         Central Electricity Authority
#
#                      geolocation_source  generation_gwh_2014  \
# 0  National Renewable Energy Laboratory                  NaN
# 1                                   WRI                  NaN
# ...

# %%
df.dtypes
# Out:
# capacity_mw            float64
# latitude               float64
# longitude              float64
# primary_fuel            object
# other_fuel1             object
# commissioning_year     float64
# source                  object
# geolocation_source      object
# generation_gwh_2014    float64
# generation_gwh_2015    float64
# generation_gwh_2016    float64
# generation_gwh_2017    float64
# generation_gwh_2018    float64
# dtype: object

# %% [markdown]
# # Feature engineering:-

# %%
df['Power_plant_age']=2022-df['commissioning_year']
df.drop(columns=["commissioning_year"],inplace=True)

# %% [markdown]
# here i have changed "commissioning_year" name to "Power_plant_age" to know the actual age of the powerplant and to analyse the datset easily

# %%
df.head()
# Out:
#    capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0          2.5   28.1839    73.2407        Solar         NaN
# 1         98.0   24.7663    74.6090         Coal         NaN
# 2         39.2   21.9038    69.3732         Wind         NaN
# 3        135.0   23.8712    91.3602          Gas         NaN
# 4       1800.0   21.9603    82.4091         Coal         Oil
#
#                                  source                    geolocation_source  \
# 0  National Renewable Energy Laboratory  National Renewable Energy Laboratory
# 1                  Ultratech Cement ltd                                   WRI
# 2                                   CDM                                   WRI
# 3         Central Electricity Authority                                   WRI
# 4         Central Electricity Authority                                   WRI
#
#    generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# ...

# %% [markdown]
# # Find catagorical & numerical data:-

# %%
categorical_columns=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        categorical_columns.append(i)
print(categorical_columns)
# Out:
# ['primary_fuel', 'other_fuel1', 'source', 'geolocation_source']

# %% [markdown]
# We can see above are the list of categorical columns.

# %%
numerical_columns=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        numerical_columns.append(i)
print(numerical_columns)
# Out:
# ['capacity_mw', 'latitude', 'longitude', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018', 'Power_plant_age']

# %% [markdown]
# we above are the list of numerical columns.

# %% [markdown]
# # Imputation technique to replace NaN values:-

# %%
#for numerical columns
df["latitude"]= df["latitude"].fillna(df["latitude"].mean())

df["longitude"]=df["longitude"].fillna(df["longitude"].median())

df["Power_plant_age"]=df["Power_plant_age"].fillna(df["Power_plant_age"].median())

df["generation_gwh_2014"]=df["generation_gwh_2014"].fillna(df["generation_gwh_2014"].median())

df["generation_gwh_2015"]=df["generation_gwh_2015"].fillna(df["generation_gwh_2015"].median())

df["generation_gwh_2016"]=df["generation_gwh_2016"].fillna(df["generation_gwh_2016"].median())

df["generation_gwh_2017"]=df["generation_gwh_2017"].fillna(df["generation_gwh_2017"].median())

df["generation_gwh_2018"]=df["generation_gwh_2018"].fillna(df["generation_gwh_2018"].median())

# %%
df.head()
# Out:
#    capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0          2.5   28.1839    73.2407        Solar         NaN
# 1         98.0   24.7663    74.6090         Coal         NaN
# 2         39.2   21.9038    69.3732         Wind         NaN
# 3        135.0   23.8712    91.3602          Gas         NaN
# 4       1800.0   21.9603    82.4091         Coal         Oil
#
#                                  source                    geolocation_source  \
# 0  National Renewable Energy Laboratory  National Renewable Energy Laboratory
# 1                  Ultratech Cement ltd                                   WRI
# 2                                   CDM                                   WRI
# 3         Central Electricity Authority                                   WRI
# 4         Central Electricity Authority                                   WRI
#
#    generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# ...

# %%
# for categorical columns

# %%
df["other_fuel1"] = df["other_fuel1"].fillna(df["other_fuel1"].mode()[0])
df["geolocation_source"] = df["geolocation_source"].fillna(df["geolocation_source"].mode()[0])

# %%
df.head()
# Out:
#    capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0          2.5   28.1839    73.2407        Solar         Oil
# 1         98.0   24.7663    74.6090         Coal         Oil
# 2         39.2   21.9038    69.3732         Wind         Oil
# 3        135.0   23.8712    91.3602          Gas         Oil
# 4       1800.0   21.9603    82.4091         Coal         Oil
#
#                                  source                    geolocation_source  \
# 0  National Renewable Energy Laboratory  National Renewable Energy Laboratory
# 1                  Ultratech Cement ltd                                   WRI
# 2                                   CDM                                   WRI
# 3         Central Electricity Authority                                   WRI
# 4         Central Electricity Authority                                   WRI
#
#    generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# ...

# %%
df.isnull().sum()
# Out:
# capacity_mw            0
# latitude               0
# longitude              0
# primary_fuel           0
# other_fuel1            0
# source                 0
# geolocation_source     0
# generation_gwh_2014    0
# generation_gwh_2015    0
# generation_gwh_2016    0
# generation_gwh_2017    0
# generation_gwh_2018    0
# Power_plant_age        0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# as we can se ther is no null values are present

# %%
#checking target columns unique values

# %%
df['primary_fuel'].unique()
# Out:
# array(['Solar', 'Coal', 'Wind', 'Gas', 'Hydro', 'Biomass', 'Oil',
#        'Nuclear'], dtype=object)

# %%
df['capacity_mw'].unique()
# Out:
# array([2.50000e+00, 9.80000e+01, 3.92000e+01, 1.35000e+02, 1.80000e+03,
#        2.50000e+02, 6.00000e+01, 1.92000e+02, 2.90000e+02, 2.10000e+02,
#        1.35000e+03, 1.34000e+02, 1.20000e+03, 1.69500e+01, 9.00000e+00,
#        2.63000e+03, 4.19330e+02, 6.00000e+02, 1.00000e+01, 1.70000e+01,
#        2.40000e+01, 6.52000e+02, 4.60000e+01, 5.00000e+01, 1.00000e+00,
#        1.65000e+01, 1.13600e+02, 1.98000e+01, 1.32000e+01, 5.00000e+00,
#        7.05000e+02, 2.80000e+01, 4.50000e+02, 1.80000e+02, 1.05000e+03,
#        5.10000e+02, 6.75000e+01, 3.00000e+02, 3.35000e+02, 1.20000e+01,
#        3.15000e+02, 3.00000e+01, 2.00000e+01, 4.20000e+01, 7.20000e+02,
#        9.00000e+01, 1.32000e+03, 1.20000e+02, 6.60000e+01, 2.70000e+02,
#        2.28000e+01, 1.50000e+01, 2.52000e+01, 1.80000e+01, 1.70000e+03,
#        2.60000e+01, 4.10000e+01, 1.37900e+03, 3.40000e+01, 1.60000e+01,
#        5.00000e+02, 8.00000e+01, 7.50000e+01, 1.21000e+03, 9.90000e+01,
# ...

# %%
#checking for empty values in our target columns

# %%
df.loc[df['primary_fuel'] == " "]
# Out:
# Empty DataFrame
# Columns: [capacity_mw, latitude, longitude, primary_fuel, other_fuel1, source, geolocation_source, generation_gwh_2014, generation_gwh_2015, generation_gwh_2016, generation_gwh_2017, generation_gwh_2018, Power_plant_age]
# Index: []

# %% [markdown]
# As we can see there is no empty values are present in primary fuel column

# %%
df.loc[df['capacity_mw'] == " "]
# Out:
# Empty DataFrame
# Columns: [capacity_mw, latitude, longitude, primary_fuel, other_fuel1, source, geolocation_source, generation_gwh_2014, generation_gwh_2015, generation_gwh_2016, generation_gwh_2017, generation_gwh_2018, Power_plant_age]
# Index: []

# %% [markdown]
# Here also we can see there is no empty values are present inside capacity_mw

# %% [markdown]
# # Data Description:-

# %%
df.describe()
# Out:
#        capacity_mw    latitude   longitude  generation_gwh_2014  \
# count   907.000000  907.000000  907.000000           907.000000
# mean    326.223755   21.197918   77.427103          1516.689956
# std     590.085456    6.079148    4.815073          2785.604307
# min       0.000000    8.168900   68.644700             0.000000
# 25%      16.725000   17.072000   74.388900           801.123775
# 50%      59.200000   21.281800   76.719500           801.123775
# 75%     385.250000   25.176450   79.206100           801.123775
# max    4760.000000   34.649000   95.408000         28127.000000
#
#        generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# count           907.000000           907.000000           907.000000
# mean           1510.071296          1565.361383          1657.121797
# std            2984.994556          3005.087210          3046.862910
# min               0.000000             0.000000             0.000000
# ...

# %% [raw]
# for above observation we can see:-
#     -All the null values has been removed, so the count in all columns is same.
#     -The mean is more than the median in all the columns except latitude which means they are skewed to right.
#     -In some columns the difference is more between max and 75% so there are outliers present in most of the columns.

# %%
df.columns
# Out:
# Index(['capacity_mw', 'latitude', 'longitude', 'primary_fuel', 'other_fuel1',
#        'source', 'geolocation_source', 'generation_gwh_2014',
#        'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017',
#        'generation_gwh_2018', 'Power_plant_age'],
#       dtype='object')

# %%
categorical_columns
# Out:
# ['primary_fuel', 'other_fuel1', 'source', 'geolocation_source']

# %%
numerical_columns
# Out:
# ['capacity_mw',
#  'latitude',
#  'longitude',
#  'commissioning_year',
#  'generation_gwh_2014',
#  'generation_gwh_2015',
#  'generation_gwh_2016',
#  'generation_gwh_2017',
#  'generation_gwh_2018']

# %% [markdown]
# # Data Visualization:-

# %% [markdown]
# # -->>Univariate Analysis

# %%
print(df["primary_fuel"].value_counts())  
sns.countplot(df["primary_fuel"])
plt.show()
# Out:
# Coal       258
# Hydro      251
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         20
# Nuclear      9
# Name: primary_fuel, dtype: int64

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(20,8))
plt.subplot(1,2,2)
df.groupby('primary_fuel').size().plot(kind='pie', autopct='%.2f')
plt.title('primary_fuel', fontsize=15)
plt.show()

# %% [markdown]
# from the above plots we can see that most of the plants in INDIA uses Coal with 28.45% and Hydro with 27.67% as there fuel.And very less plants uses Nuclear fuel within 1%.

# %%
print(df["other_fuel1"].value_counts())  
sns.countplot(df["other_fuel1"])
plt.show()
# Out:
# Oil             904
# Gas               2
# Cogeneration      1
# Name: other_fuel1, dtype: int64

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(20,8))
plt.subplot(1,2,2)
df.groupby("other_fuel1").size().plot(kind='pie', autopct='%.2f')
plt.title("other_fuel1", fontsize=15)
plt.show()

# %% [markdown]
# It seems most of the plants are using Oil as the other_fuel with a value of 99.67%

# %%
print(df["geolocation_source"].value_counts())  
sns.countplot(df["geolocation_source"])
plt.show()
# Out:
# WRI                                     784
# Industry About                          119
# National Renewable Energy Laboratory      4
# Name: geolocation_source, dtype: int64

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
df.groupby("geolocation_source").size().plot(kind='pie', autopct='%.2f')
plt.title("geolocation_source", fontsize=15)
plt.show()

# %% [markdown]
# above charts shows that maximum power plants source is WRI.And very less plants has National Renewable Energy Laboratory as source

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
df.groupby("source").size().plot(kind='pie', autopct='%.2f')
plt.title("source", fontsize=15)
plt.show()

# %% [markdown]
# there is lots of source,among them mostly used source is central electricity authority which is 57.22% and then CDM of 13.67%

# %%
numerical_columns
# Out:
# ['capacity_mw',
#  'latitude',
#  'longitude',
#  'commissioning_year',
#  'generation_gwh_2014',
#  'generation_gwh_2015',
#  'generation_gwh_2016',
#  'generation_gwh_2017',
#  'generation_gwh_2018']

# %% [markdown]
# Distribution plot for NUmerical columns:-

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in numerical_columns:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df[column],color="red")
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# -from above observation we can see that only latitude column is normally distributed.

# %% [markdown]
# # Bivariate Analysis:-

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between latitude and primary_fuel')
sns.barplot(df['primary_fuel'],df["latitude"],palette="husl")
# Out:
# <AxesSubplot:title={'center':'Comparision between latitude and primary_fuel'}, xlabel='primary_fuel', ylabel='latitude'>

# %% [markdown]
# we can see the fuel type Solar has high latitude followed by Hydro, Coal and Gas and remaining sources.

# %%
plt.figure(figsize = (10,6))
plt.title("Comparision between primary_fuel and Power plant age")
sns.barplot(x = "primary_fuel", y = "Power_plant_age", data = df,palette="Set2")
plt.show()

# %% [raw]
# from above fig we can see,
# -Hydro,Nuclear and Oil fuels are old power plants.
# -and solar and coal fuels are new as compared to others

# %%
sns.scatterplot(x='primary_fuel',y='geolocation_source',data=df,palette="husl")
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='geolocation_source'>

# %% [markdown]
# geolocation_source= WRI has all the types of fuels used but Industry About and National Renewable Energy Laboratory has only solar as fuel.

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Power_plant_age and capacity_mw')
sns.regplot(df['Power_plant_age'],df['capacity_mw'])
# Out:
# <AxesSubplot:title={'center':'Comparision between Power_plant_age and capacity_mw'}, xlabel='Power_plant_age', ylabel='capacity_mw'>

# %% [markdown]
# From the plot we can observe that there is negative linear relationship between feature and label also we can infer that the capacity of older power plants is very less compared to the power plants which are started recently.

# %%
plt.figure(figsize = (10,6))
plt.title("Comparision between generation_gwh_2018 and capacity_mw")
sns.scatterplot(x = "generation_gwh_2018", y = "capacity_mw", data = df,color="g")
plt.show()

# %% [raw]
# We can slearly see that the linear relationship between the feature and the label.
# Here the electricity generation reported for the year 2018 has capacity above 1000 mw also as the generation growth increases, the capacity of plant is also increasing moderately.

# %%
plt.figure(figsize = (8,6))
sns.barplot(x = "geolocation_source", y = "capacity_mw", data = df)
plt.show()

# %% [raw]
# here the capacity of geolocation source WRI is maximum which has capacity more tahn 350 mega watts.

# %% [markdown]
# # Relation between targets:-

# %%
plt.figure(figsize = (10,6))
plt.title("Comparision between primary_fuel and capacity_mw")
sns.barplot(x = "primary_fuel", y = "capacity_mw", data = df)
plt.show()

# %% [markdown]
# Here we can see the plants which uses Nuclear and Coal as fuel has more capacity than other plants.

# %% [markdown]
# # Multivariate Analysis:-

# %%
g=sns.PairGrid(df, hue="primary_fuel")
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %%
g2=sns.PairGrid(df,hue="capacity_mw")
g2.map_diag(sns.histplot)
g2.map_offdiag(sns.scatterplot)
g.add_legend()

# %% [markdown]
# # Checking Outliers:-

# %%
plt.figure(figsize=(10,10),facecolor='white')
plotnumber=1
for column in numerical_columns:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(df[column],color="red")
        plt.xlabel(column,fontsize=12)
    plotnumber+=1
plt.tight_layout()

# %%
df.plot(kind='box',subplots=True,layout=(5,5),figsize=(15,10))
# Out:
# capacity_mw               AxesSubplot(0.125,0.749828;0.133621x0.130172)
# latitude               AxesSubplot(0.285345,0.749828;0.133621x0.130172)
# longitude               AxesSubplot(0.44569,0.749828;0.133621x0.130172)
# generation_gwh_2014    AxesSubplot(0.606034,0.749828;0.133621x0.130172)
# generation_gwh_2015    AxesSubplot(0.766379,0.749828;0.133621x0.130172)
# generation_gwh_2016       AxesSubplot(0.125,0.593621;0.133621x0.130172)
# generation_gwh_2017    AxesSubplot(0.285345,0.593621;0.133621x0.130172)
# generation_gwh_2018     AxesSubplot(0.44569,0.593621;0.133621x0.130172)
# Power_plant_age        AxesSubplot(0.606034,0.593621;0.133621x0.130172)
# dtype: object

# %% [markdown]
# we can see there is outliers present in this but capacity_mw is my target so no need to remove outliers in that column.

# %% [markdown]
# # Removing outliers:-

# %%
features = df[['longitude',  'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017','generation_gwh_2018','Power_plant_age']]

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(features))
z
# Out:
#      longitude  generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0     0.869917             0.257022             0.267783             0.275737
# 1     0.585590             0.257022             0.267783             0.275737
# 2     1.673567             0.257022             0.267783             0.275737
# 3     2.895239             0.322873             0.223348             0.226194
# 4     1.035238             0.545554             1.476964             1.557432
# ..         ...                  ...                  ...                  ...
# 902   0.014609             0.257022             0.505833             0.443415
# 903   0.153415             0.257022             0.267783             0.275737
# 904   0.383592             0.257022             0.267783             0.275737
# 905   0.764564             0.257022             0.267783             0.275737
# 906   0.010327             0.257022             0.267783             0.275737
#
# ...

# %%
new_df=df[(z<3).all(axis=1)] 
new_df
# Out:
#      capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0            2.5   28.1839    73.2407        Solar         Oil
# 1           98.0   24.7663    74.6090         Coal         Oil
# 2           39.2   21.9038    69.3732         Wind         Oil
# 3          135.0   23.8712    91.3602          Gas         Oil
# 4         1800.0   21.9603    82.4091         Coal         Oil
# ..           ...       ...        ...          ...         ...
# 902       1600.0   16.2949    77.3568         Coal         Oil
# 903          3.0   12.8932    78.1654        Solar         Oil
# 904         25.5   15.2758    75.5811         Wind         Oil
# 905         80.0   24.3500    73.7477         Coal         Oil
# 906         16.5    9.9344    77.4768         Wind         Oil
#
#                                    source  \
# 0    National Renewable Energy Laboratory
# 1                    Ultratech Cement ltd
# 2                                     CDM
# ...

# %%
df.shape
# Out:
# (907, 13)

# %% [markdown]
#  Before removing the outliers we had 907 rows and 13 columns.

# %%
new_df.shape
# Out:
# (851, 13)

# %% [markdown]
# After removing the outliers we have 851 rows and 13 columns.

# %% [markdown]
# # % of data loss:-

# %%
data_loss = (907-851)/907*100
data_loss
# Out:
# 6.174200661521499

# %% [markdown]
# Using Zscore i have lost 6.17% of data.

# %% [markdown]
# Which is less than 10%.But still let me have a look into IQR method also.

# %% [markdown]
# # IQR (Inter Quantile Range) method:-

# %%
# 1st quantile
Q1=features.quantile(0.25)
# 3rd quantile
Q3=features.quantile(0.75)
# IQR
IQR=Q3-Q1

# %%
df1=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]

# %%
df1.shape
# Out:
# (420, 13)

# %% [markdown]
# Using IQR method the dataframe has 420 rows and 13 columns.

# %% [markdown]
# # % of data loss:-

# %%
data_loss=(907-420)/907*100
data_loss
# Out:
# 53.69349503858876

# %% [markdown]
# Using IQR method i am losing 54% of data

# %% [markdown]
# so here we considering Zscore method for better result.

# %% [markdown]
# # Encoding the categorical columns using Label Encoding:-

# %%
categorical_col=[]
for i in new_df.dtypes.index:
    if new_df.dtypes[i]=='object':
        categorical_col.append(i)
print(categorical_col)
# Out:
# ['primary_fuel', 'other_fuel1', 'source', 'geolocation_source']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE=LabelEncoder()
new_df[categorical_col]= new_df[categorical_col].apply(LE.fit_transform)

# %%
new_df[categorical_col]
# Out:
#      primary_fuel  other_fuel1  source  geolocation_source
# 0               6            2     109                   1
# 1               1            2     174                   2
# 2               7            2      21                   2
# 3               2            2      22                   2
# 4               1            2      22                   2
# ..            ...          ...     ...                 ...
# 902             1            2      22                   2
# 903             6            2      77                   0
# 904             7            2      21                   2
# 905             1            2      59                   2
# 906             7            2      21                   2
#
# [851 rows x 4 columns]

# %% [markdown]
# The categorical columns has been converted into numerical columns by using label encoding.

# %% [markdown]
# # Checking Correlation:-

# %%
cor=new_df.corr()
cor
# Out:
#                      capacity_mw  latitude  longitude  primary_fuel  \
# capacity_mw             1.000000  0.050588   0.257582     -0.398039
# latitude                0.050588  1.000000  -0.014145     -0.002561
# longitude               0.257582 -0.014145   1.000000     -0.382975
# primary_fuel           -0.398039 -0.002561  -0.382975      1.000000
# other_fuel1            -0.001758  0.037049   0.029191      0.006463
# source                 -0.275724  0.069430  -0.235719      0.038558
# geolocation_source      0.234543 -0.203340   0.263739     -0.478601
# generation_gwh_2014     0.620202  0.081661   0.119473     -0.250101
# generation_gwh_2015     0.680949  0.071346   0.154522     -0.276308
# generation_gwh_2016     0.750088  0.057301   0.195299     -0.286624
# generation_gwh_2017     0.788972  0.071296   0.196529     -0.289232
# generation_gwh_2018     0.815198  0.064558   0.204421     -0.298364
# Power_plant_age        -0.241487 -0.097033  -0.080034      0.074358
#
# ...

# %% [markdown]
# This gives the correlation between the denpendent and independent variables

# %%
plt.figure(figsize=(10,8))
sns.heatmap(new_df.corr(),annot=True,linewidth=0.01,linecolor='black',fmt='0.0%')
# Out:
# <AxesSubplot:>

# %% [raw]
# Correlation between primary_fuel and features :-
#     -The label Fuel_Type is less correlated with Power_plant_age and source.
#     -The label is negatively correlated with geolocation_source, longitude, capacity_mw, and all generation_gwh years.
#
# Correlation between capacity_mw and features:-
#     - the label is negatively correlated with the feature primary_fuel, source and Power_plant_age.
#     -The label capacity_mw is highly positively correlated with the features generation_gwh_2018, features                      generation_gwh_2017, generation_gwh_2016, generation_gwh_2015, generation_gwh_2014.
#     -The columns other_fuel1 and latitude have no relation with the label, so we can drop them.

# %% [markdown]
# # Visualizing the correlation using bar plot:-

# %%
#For primary_fuel...

# %%
plt.figure(figsize=(22,7))
new_df.corr()['primary_fuel'].sort_values(ascending=False).drop(['primary_fuel']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=10)
plt.ylabel('target',fontsize=10)
plt.title('correlation between label and feature using bar plot',fontsize=20)
plt.show()

# %% [markdown]
# we can see other_fuel1 and latitude is very less correlated with primary_fuel so i can drop it.

# %%
#for capacity_mw...

# %%
plt.figure(figsize=(22,7))
new_df.corr()['capacity_mw'].sort_values(ascending=False).drop(['capacity_mw']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=10)
plt.ylabel('target',fontsize=10)
plt.title('correlation between label and feature using bar plot',fontsize=20)
plt.show()

# %% [markdown]
# Here also Lattitude and otherfuel_1 have less correlation with target variable, i can drop these columns.

# %%
#droping those unnessesary columns
new_df=new_df.drop(["other_fuel1"],axis=1)
new_df=new_df.drop(["latitude"],axis=1)

# %%
new_df.head()
# Out:
#    capacity_mw  longitude  primary_fuel  source  geolocation_source  \
# 0          2.5    73.2407             6     109                   1
# 1         98.0    74.6090             1     174                   2
# 2         39.2    69.3732             7      21                   2
# 3        135.0    91.3602             2      22                   2
# 4       1800.0    82.4091             1      22                   2
#
#    generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0           801.123775           711.181225           737.205450
# 1           801.123775           711.181225           737.205450
# 2           801.123775           711.181225           737.205450
# 3           617.789264           843.747000           886.004428
# 4          3035.550000          5916.370000          6243.000000
#
#    generation_gwh_2017  generation_gwh_2018  Power_plant_age
# 0           817.977250           751.644375             11.0
# ...

# %% [markdown]
# we can see Lattitude and otherfuel_1 column is not present in our dataset

# %% [markdown]
# # i) lets Prediction for primary_fuel :-

# %% [markdown]
# # Separating the features and label into x & y:-

# %%
x=new_df.drop("primary_fuel", axis=1)
y=new_df["primary_fuel"]

# %%
x.shape
# Out:
# (851, 10)

# %%
y.shape
# Out:
# (851,)

# %% [markdown]
# # Checking for skewness:-

# %%
x.skew()
# Out:
# capacity_mw            2.170245
# longitude              0.945877
# source                 1.734252
# geolocation_source    -2.066536
# generation_gwh_2014    2.943026
# generation_gwh_2015    2.714999
# generation_gwh_2016    2.645786
# generation_gwh_2017    2.546541
# generation_gwh_2018    2.597029
# Power_plant_age        1.280800
# dtype: float64

# %% [markdown]
# we can see the skewness in all the columns but the columns source and geolocation_source are categorical so no need to remove skewness in these columns. Let's remove the skewness in the numerical columns using yeo-johnson method.

# %% [markdown]
# # Removing skewness using yeo_johnson method:-

# %%
skew = ['capacity_mw','longitude','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017','generation_gwh_2018','Power_plant_age']

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# %%
x[skew]=scaler.fit_transform(x[skew].values)
x[skew].head()
# Out:
#    capacity_mw  longitude  generation_gwh_2014  generation_gwh_2015  \
# 0    -1.677389  -0.922012            -0.044061            -0.049141
# 1     0.220284  -0.499829            -0.044061            -0.049141
# 2    -0.274381  -2.377759            -0.044061            -0.049141
# 3     0.391670   2.430594            -0.268922             0.093773
# 4     1.731859   1.261979             1.426798             2.286603
#
#    generation_gwh_2016  generation_gwh_2017  generation_gwh_2018  \
# 0            -0.046103            -0.035226            -0.057181
# 1            -0.046103            -0.035226            -0.057181
# 2            -0.046103            -0.035226            -0.057181
# 3             0.105691            -0.199692            -0.194159
# 4             2.276671             1.983083             2.347272
#
#    Power_plant_age
# 0        -1.110868
# 1         0.051442
# 2         0.051442
# 3        -0.249172
# 4        -1.779328

# %%
x.skew()
# Out:
# capacity_mw            0.016303
# longitude             -0.000128
# source                 1.734252
# geolocation_source    -2.066536
# generation_gwh_2014    0.232399
# generation_gwh_2015    0.163587
# generation_gwh_2016    0.147035
# generation_gwh_2017    0.127152
# generation_gwh_2018    0.133691
# Power_plant_age        0.022168
# dtype: float64

# %% [markdown]
# now we can see we have removed the skewness in all the numerical columns.

# %%
# After removing let's check how the data has been distributed in all columns.

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in x[skew]:
    if plotnumber<=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(x[column],color='g',kde_kws={"shade": True},hist=False)
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# It looks like the skewness is removed completely.

# %% [markdown]
# # Scaling the data using standard scaler:-

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#      capacity_mw  longitude    source  geolocation_source  \
# 0      -1.677389  -0.922012  1.397951           -1.036523
# 1       0.220284  -0.499829  2.821796            0.407145
# 2      -0.274381  -2.377759 -0.529717            0.407145
# 3       0.391670   2.430594 -0.507812            0.407145
# 4       1.731859   1.261979 -0.507812            0.407145
# ..           ...        ...       ...                 ...
# 846     1.672840   0.231932 -0.507812            0.407145
# 847    -1.598186   0.421592  0.696980           -2.480190
# 848    -0.507278  -0.224400 -0.529717            0.407145
# 849     0.111201  -0.760624  0.302685            0.407145
# 850    -0.741846   0.260758 -0.529717            0.407145
#
#      generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0              -0.044061            -0.049141            -0.046103
# 1              -0.044061            -0.049141            -0.046103
# ...

# %% [markdown]
# # Checking VIF values:-

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
for i in range(len(x.columns))]
vif["Features"] = x.columns

# Let's check the values
vif
# Out:
#    VIF values             Features
# 0    1.814763          capacity_mw
# 1    1.193803            longitude
# 2    1.412954               source
# 3    1.591030   geolocation_source
# 4    3.625589  generation_gwh_2014
# 5    6.189896  generation_gwh_2015
# 6    9.959672  generation_gwh_2016
# 7    9.765110  generation_gwh_2017
# 8    8.960648  generation_gwh_2018
# 9    1.158205      Power_plant_age

# %% [markdown]
# The VIF value is less than 10 in all the columns which means we don't have multicollinearity problem.

# %%
y.value_counts()
# Out:
# 1    238
# 3    220
# 6    126
# 7    123
# 2     65
# 0     50
# 5     20
# 4      9
# Name: primary_fuel, dtype: int64

# %% [markdown]
# The data is not balanced, so we have to balance the data by over sampling.

# %%
from imblearn.over_sampling import SMOTE

# %%
SM=SMOTE()
x,y=SM.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 6    238
# 1    238
# 7    238
# 2    238
# 3    238
# 0    238
# 5    238
# 4    238
# Name: primary_fuel, dtype: int64

# %%
x.head()
# Out:
#    capacity_mw  longitude    source  geolocation_source  generation_gwh_2014  \
# 0    -1.677389  -0.922012  1.397951           -1.036523            -0.044061
# 1     0.220284  -0.499829  2.821796            0.407145            -0.044061
# 2    -0.274381  -2.377759 -0.529717            0.407145            -0.044061
# 3     0.391670   2.430594 -0.507812            0.407145            -0.268922
# 4     1.731859   1.261979 -0.507812            0.407145             1.426798
#
#    generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0            -0.049141            -0.046103            -0.035226
# 1            -0.049141            -0.046103            -0.035226
# 2            -0.049141            -0.046103            -0.035226
# 3             0.093773             0.105691            -0.199692
# 4             2.286603             2.276671             1.983083
#
#    generation_gwh_2018  Power_plant_age
# 0            -0.057181        -1.110868
# ...

# %% [markdown]
# # Finding Best Random State and Accuracy:-

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
from sklearn.tree import DecisionTreeClassifier

maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30, random_state =i)
    DTC = DecisionTreeClassifier()
    DTC.fit(x_train, y_train)
    pred = DTC.predict(x_test)
    acc=accuracy_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu," on Random_state ",maxRS)
# Out:
# Best accuracy is  0.9003496503496503  on Random_state  147

# %% [markdown]
# # Creating train test split:-

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=maxRS)

# %% [markdown]
# Classification Algorithms:-

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.ensemble import GradientBoostingClassifier, BaggingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score

# %% [markdown]
# # Decision Tree Classifier:-

# %%
DTC = DecisionTreeClassifier()
DTC.fit(x_train,y_train)

#Prediction
predDTC = DTC.predict(x_test)

print('Accuracy is : ',accuracy_score(y_test, predDTC))
print(confusion_matrix(y_test, predDTC))
print(classification_report(y_test,predDTC))
# Out:
# Accuracy is :  0.8916083916083916
# [[61  3  1  0  0  0  0  0]
#  [ 3 35  5  9  4  2  0  0]
#  [ 0  6 69  3  0  4  0  0]
#  [ 0  6  4 60  3  1  0  0]
#  [ 0  0  0  1 51  0  0  0]
#  [ 0  2  5  0  0 71  0  0]
#  [ 0  0  0  0  0  0 79  0]
#  [ 0  0  0  0  0  0  0 84]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95        65
#            1       0.67      0.60      0.64        58
#            2       0.82      0.84      0.83        82
#            3       0.82      0.81      0.82        74
#            4       0.88      0.98      0.93        52
#            5       0.91      0.91      0.91        78
#            6       1.00      1.00      1.00        79
#            7       1.00      1.00      1.00        84
#
#     accuracy                           0.89       572
#    macro avg       0.88      0.89      0.88       572
# weighted avg       0.89      0.89      0.89       572

# %% [markdown]
# Accuracy by using Decision Tree Classifier is 89%

# %%
cm = confusion_matrix(y_test,predDTC)

x_axis_labels = ["0","1","2","3","4","5","6","7"]
y_axis_labels = ["0","1","2","3","4","5","6","7"]

f , ax = plt.subplots(figsize=(7,7))
sns.heatmap(cm, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, cmap="BuGn",xticklabels=x_axis_labels,yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Decision Tree Classifier')
plt.show()

# %% [markdown]
# here is confusion matrix for DecisionTreeClassifier

# %% [markdown]
# # Random Forest Classifier:-

# %%
RFC = RandomForestClassifier()
RFC.fit(x_train,y_train)
# Prediction
predRFC = RFC.predict(x_test)

print('Accuracy is : ',accuracy_score(y_test, predRFC))
print(confusion_matrix(y_test, predRFC))
print(classification_report(y_test,predRFC))
# Out:
# Accuracy is :  0.9213286713286714
# [[65  0  0  0  0  0  0  0]
#  [ 2 40  7  7  0  2  0  0]
#  [ 0  4 70  3  1  4  0  0]
#  [ 0  3  4 66  1  0  0  0]
#  [ 0  0  0  0 52  0  0  0]
#  [ 0  3  4  0  0 71  0  0]
#  [ 0  0  0  0  0  0 79  0]
#  [ 0  0  0  0  0  0  0 84]]
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        65
#            1       0.80      0.69      0.74        58
#            2       0.82      0.85      0.84        82
#            3       0.87      0.89      0.88        74
#            4       0.96      1.00      0.98        52
#            5       0.92      0.91      0.92        78
#            6       1.00      1.00      1.00        79
#            7       1.00      1.00      1.00        84
#
#     accuracy                           0.92       572
#    macro avg       0.92      0.92      0.92       572
# weighted avg       0.92      0.92      0.92       572

# %% [markdown]
# The accuracy by using Random Forest Classifier is 92%.

# %%
cm = confusion_matrix(y_test,predRFC)

x_axis_labels = ["0","1","2","3","4","5","6","7"]
y_axis_labels = ["0","1","2","3","4","5","6","7"]

f , ax = plt.subplots(figsize=(7,7))
sns.heatmap(cm, annot = True,linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="BuGn",xticklabels=x_axis_labels,yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for RandomForestClassifier')
plt.show()

# %% [markdown]
# # Support Vector Machine Classifier:-

# %%
svc = SVC()
svc.fit(x_train,y_train)

# Prediction
predsvc=svc.predict(x_test)

print('Accuracy is : ',accuracy_score(y_test, predsvc))
print(confusion_matrix(y_test, predsvc))
print(classification_report(y_test,predsvc))
# Out:
# Accuracy is :  0.7972027972027972
# [[56  0  0  0  0  0  0  9]
#  [ 6 24 14  3  5  2  0  4]
#  [ 0  4 44  7  5 20  0  2]
#  [ 0  1 10 47  5  0  0 11]
#  [ 0  0  0  0 52  0  0  0]
#  [ 2  2  0  0  0 71  0  3]
#  [ 0  0  0  0  0  0 79  0]
#  [ 0  0  1  0  0  0  0 83]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87        65
#            1       0.77      0.41      0.54        58
#            2       0.64      0.54      0.58        82
#            3       0.82      0.64      0.72        74
#            4       0.78      1.00      0.87        52
#            5       0.76      0.91      0.83        78
#            6       1.00      1.00      1.00        79
#            7       0.74      0.99      0.85        84
#
#     accuracy                           0.80       572
#    macro avg       0.80      0.79      0.78       572
# weighted avg       0.80      0.80      0.78       572

# %% [markdown]
# The accuracy using Support Vector Machine Classifier is 79%.

# %%
cm = confusion_matrix(y_test,predsvc)

x_axis_labels = ["0","1","2","3","4","5","6","7"]
y_axis_labels = ["0","1","2","3","4","5","6","7"]

f , ax = plt.subplots(figsize=(7,7))
sns.heatmap(cm, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, cmap="BuGn",xticklabels=x_axis_labels,yticklabels=y_axis_labels)

plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Support Vector Machine Classifier')
plt.show()

# %% [markdown]
# # KNeighbors Classifier:-

# %%
knn = KNN()
knn.fit(x_train,y_train)
# Prediction
predknn = knn.predict(x_test)

print('Accuracy is : ',accuracy_score(y_test, predknn))
print(confusion_matrix(y_test, predknn))
print(classification_report(y_test,predknn))
# Out:
# Accuracy is :  0.8653846153846154
# [[63  0  0  0  0  0  0  2]
#  [ 4 30 12  4  4  1  0  3]
#  [ 0  4 65  4  2  5  0  2]
#  [ 0  6 10 56  1  0  0  1]
#  [ 0  0  0  0 52  0  0  0]
#  [ 4  1  4  0  0 68  0  1]
#  [ 0  0  0  0  0  0 79  0]
#  [ 0  0  0  0  0  2  0 82]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93        65
#            1       0.73      0.52      0.61        58
#            2       0.71      0.79      0.75        82
#            3       0.88      0.76      0.81        74
#            4       0.88      1.00      0.94        52
#            5       0.89      0.87      0.88        78
#            6       1.00      1.00      1.00        79
#            7       0.90      0.98      0.94        84
#
#     accuracy                           0.87       572
#    macro avg       0.86      0.86      0.86       572
# weighted avg       0.86      0.87      0.86       572

# %% [markdown]
# The accuracy using KNeighbors Classifier is 86%.

# %%
cm = confusion_matrix(y_test,predknn)

x_axis_labels = ["0","1","2","3","4","5","6","7"]
y_axis_labels = ["0","1","2","3","4","5","6","7"]

f , ax = plt.subplots(figsize=(7,7))
sns.heatmap(cm, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, cmap="BuGn",xticklabels=x_axis_labels,yticklabels=y_axis_labels)

plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for KNN Classifier')
plt.show()

# %% [markdown]
# # Gradient Boosting Classifier:-

# %%
GB = GradientBoostingClassifier()
GB.fit(x_train,y_train)
# Prediction
predGB = GB.predict(x_test)

print('Accuracy is : ',accuracy_score(y_test, predGB))
print(confusion_matrix(y_test, predGB))
print(classification_report(y_test,predGB))
# Out:
# Accuracy is :  0.9038461538461539
# [[64  1  0  0  0  0  0  0]
#  [ 3 37  8  6  3  1  0  0]
#  [ 0  6 64  6  2  4  0  0]
#  [ 0  2  6 65  1  0  0  0]
#  [ 0  0  0  0 52  0  0  0]
#  [ 0  3  3  0  0 72  0  0]
#  [ 0  0  0  0  0  0 79  0]
#  [ 0  0  0  0  0  0  0 84]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        65
#            1       0.76      0.64      0.69        58
#            2       0.79      0.78      0.79        82
#            3       0.84      0.88      0.86        74
#            4       0.90      1.00      0.95        52
#            5       0.94      0.92      0.93        78
#            6       1.00      1.00      1.00        79
#            7       1.00      1.00      1.00        84
#
#     accuracy                           0.90       572
#    macro avg       0.90      0.90      0.90       572
# weighted avg       0.90      0.90      0.90       572

# %% [markdown]
# The accuracy using Gradient Boosting Classifier is 90%.

# %%
cm = confusion_matrix(y_test,predGB)

x_axis_labels = ["0","1","2","3","4","5","6","7"]
y_axis_labels = ["0","1","2","3","4","5","6","7"]

f , ax = plt.subplots(figsize=(7,7))
sns.heatmap(cm, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, cmap="BuGn",xticklabels=x_axis_labels,yticklabels=y_axis_labels)

plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Gradient Boosting Classifier')
plt.show()

# %% [markdown]
# # Checking Cross Validation Score:-

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(DTC,x,y,cv=5).mean())    #for Decision tree
# Out:
# 0.8687014781047105

# %%
print(cross_val_score(RFC,x,y,cv=5).mean())     #for random forest
# Out:
# 0.9143859649122807

# %%
print(cross_val_score(svc,x,y,cv=5).mean())     #for support  vector
# Out:
# 0.7919988948749828

# %%
print(cross_val_score(knn,x,y,cv=5).mean())     #for knn
# Out:
# 0.8550435142975548

# %%
print(cross_val_score(GB,x,y,cv=5).mean())       #for gradient boost
# Out:
# 0.9007224754800387

# %% [markdown]
# almost all models perfermed well among all Random forest classifier have less diffrence in model accuracy and cross validation score

# %% [markdown]
# # Hyperparameter Tuning:-

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'max_features':['auto','sqrt','log2'],
            'max_depth':[15,20,25,35],
            'n_estimators':[100,200,300,400],
            'criterion':['gini','entropy']}

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
GCV.best_params_       # it takes more than 1hr to run,thats why i am considering best parameter by myself

# %%
Final_mod=RandomForestClassifier(criterion='gini',max_depth=25, max_features='auto', n_estimators=400)
Final_mod.fit(x_train,y_train)
pred=Final_mod.predict(x_test)
acc=accuracy_score(y_test, pred)
print(acc*100)
# Out:
# 92.13286713286713

# %%
primary_fuel =RandomForestClassifier(criterion='gini',max_depth=25, max_features='auto', n_estimators=400)
primary_fuel.fit(x_train, y_train)
pred = primary_fuel.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 92.83216783216784

# %% [markdown]
# its tune upto 1-2%

# %% [markdown]
# This is the final accuracy of the model after tuning which is 92.83%

# %% [markdown]
# # Saving the model:-

# %%
import joblib
joblib.dump(primary_fuel,"power_plant_primary_fuel.pkl")
# Out:
# ['power_plant_primary_fuel.pkl']

# %% [markdown]
# # Lets Predicting the saved model:-

# %%
model=joblib.load("power_plant_primary_fuel.pkl")

#Prediction
prediction = model.predict(x_test)
prediction
# Out:
# array([7, 4, 2, 0, 0, 5, 7, 6, 6, 6, 0, 2, 0, 2, 0, 4, 7, 5, 4, 1, 7, 5,
#        7, 6, 5, 6, 2, 2, 3, 4, 7, 7, 1, 2, 6, 1, 1, 6, 4, 5, 5, 5, 6, 0,
#        4, 6, 4, 2, 5, 1, 2, 5, 2, 1, 3, 3, 6, 4, 7, 5, 5, 2, 5, 5, 1, 2,
#        0, 4, 7, 5, 7, 7, 5, 7, 7, 3, 5, 0, 6, 0, 7, 6, 3, 0, 0, 6, 6, 7,
#        7, 5, 4, 2, 5, 7, 5, 1, 4, 6, 5, 1, 4, 7, 3, 1, 2, 0, 0, 3, 6, 2,
#        4, 2, 0, 5, 0, 1, 0, 2, 6, 2, 5, 7, 1, 0, 7, 0, 7, 6, 5, 6, 6, 6,
#        4, 6, 0, 2, 2, 6, 6, 7, 6, 5, 2, 7, 4, 4, 6, 0, 3, 7, 7, 2, 3, 7,
#        7, 2, 2, 5, 2, 2, 3, 6, 0, 4, 7, 5, 0, 6, 2, 6, 3, 5, 7, 4, 5, 1,
#        2, 4, 5, 5, 1, 3, 2, 3, 5, 4, 6, 7, 7, 2, 4, 7, 7, 2, 3, 3, 0, 6,
#        0, 7, 0, 4, 6, 3, 2, 7, 4, 1, 2, 2, 2, 6, 1, 7, 1, 2, 3, 5, 7, 4,
#        1, 2, 6, 2, 0, 0, 1, 1, 1, 2, 5, 4, 7, 3, 4, 7, 3, 1, 2, 3, 0, 6,
#        7, 4, 7, 0, 2, 7, 4, 6, 4, 3, 3, 5, 4, 3, 0, 2, 2, 2, 7, 3, 5, 6,
#        7, 1, 0, 0, 6, 0, 1, 2, 6, 2, 4, 2, 6, 2, 1, 6, 3, 3, 0, 7, 2, 3,
# ...

# %%
pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"]).T   #T for table format
# Out:
#      Predicted  Original
# 0            7         7
# 1            4         4
# 2            2         2
# 3            0         0
# 4            0         0
# ..         ...       ...
# 567          5         1
# 568          1         3
# 569          2         2
# 570          5         5
# 571          7         7
#
# [572 rows x 2 columns]

# %% [markdown]
# it looks like almost all the actual and predicted values are almost same.

# %% [markdown]
# # 2). Prediction for capacity_mw

# %% [markdown]
# # Separating the features and label variables into x and y

# %%
x1=new_df.drop("capacity_mw", axis=1)
y1=new_df["capacity_mw"]

# %%
x1.shape
# Out:
# (851, 10)

# %%
y1.shape
# Out:
# (851,)

# %% [markdown]
# # skewness checking:-

# %%
x1.skew()
# Out:
# longitude              0.945877
# primary_fuel           0.413759
# source                 1.734252
# geolocation_source    -2.066536
# generation_gwh_2014    2.943026
# generation_gwh_2015    2.714999
# generation_gwh_2016    2.645786
# generation_gwh_2017    2.546541
# generation_gwh_2018    2.597029
# Power_plant_age        1.280800
# dtype: float64

# %% [markdown]
# Here columns source and geolocation_source are categorical so no need to remove skewness in these columns.
# Except these two and primary_fuel all the columns having skewness.

# %% [markdown]
# # Removing skewness using yeo-johnson method:-

# %%
skew1 = ['longitude','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017','generation_gwh_2018','Power_plant_age']

from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# %%
x1[skew1] = scaler.fit_transform(x1[skew1].values)
x1[skew1].head()
# Out:
#    longitude  generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0  -0.922017            -0.021192            -0.028353            -0.025970
# 1  -0.499918            -0.021192            -0.028353            -0.025970
# 2  -2.377242            -0.021192            -0.028353            -0.025970
# 3   2.431133            -0.249076             0.114643             0.125811
# 4   1.262067             1.402492             2.209237             2.202688
#
#    generation_gwh_2017  generation_gwh_2018  Power_plant_age
# 0            -0.017684            -0.037438        -1.109091
# 1            -0.017684            -0.037438         0.046855
# 2            -0.017684            -0.037438         0.046855
# 3            -0.183330            -0.175600        -0.253375
# 4             1.935643             2.269543        -1.769444

# %%
x1.skew()
# Out:
# longitude              0.000603
# primary_fuel           0.413759
# source                 1.734252
# geolocation_source    -2.066536
# generation_gwh_2014   -0.040049
# generation_gwh_2015   -0.048208
# generation_gwh_2016   -0.048254
# generation_gwh_2017   -0.036094
# generation_gwh_2018   -0.053122
# Power_plant_age        0.055169
# dtype: float64

# %% [markdown]
# now we can see we have removed the skewness in all columns.

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in x1[skew1]:
    if plotnumber<=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(x1[column],color='indigo',kde_kws={"shade": True},hist=False)
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [raw]
# Here we can see all the columns are distribudes properly.
# It looks like the skewness is removed completely

# %% [markdown]
# # Scaling the data using standard scaler:-

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x1 = pd.DataFrame(scaler.fit_transform(x1), columns=x1.columns)
x1
# Out:
#      longitude  primary_fuel    source  geolocation_source  \
# 0    -0.922017      1.175506  1.397951           -1.036523
# 1    -0.499918     -0.975797  2.821796            0.407145
# 2    -2.377242      1.605767 -0.529717            0.407145
# 3     2.431133     -0.545536 -0.507812            0.407145
# 4     1.262067     -0.975797 -0.507812            0.407145
# ..         ...           ...       ...                 ...
# 846   0.231811     -0.975797 -0.507812            0.407145
# 847   0.421491      1.175506  0.696980           -2.480190
# 848  -0.224521      1.605767 -0.529717            0.407145
# 849  -0.760666     -0.975797  0.302685            0.407145
# 850   0.260640      1.605767 -0.529717            0.407145
#
#      generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0              -0.021192            -0.028353            -0.025970
# 1              -0.021192            -0.028353            -0.025970
# ...

# %% [markdown]
# I have scaled the data using standard scalarizaion method to overcome with the issue of data biasness.

# %% [markdown]
# As we have observed in the heat map there is multicollinearity issue exists in the data, So let's check the VIF value and if the columns have VIF greater than 10 then we can drop those columns.

# %% [markdown]
# # Checking VIF:-

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x1.values,i)
for i in range(len(x1.columns))]
vif["Features"] = x1.columns

# Let's check the values
vif
# Out:
#    VIF values             Features
# 0    1.309981            longitude
# 1    1.677205         primary_fuel
# 2    1.501624               source
# 3    1.874922   geolocation_source
# 4    3.459101  generation_gwh_2014
# 5    5.867453  generation_gwh_2015
# 6    9.568319  generation_gwh_2016
# 7    9.114508  generation_gwh_2017
# 8    8.527023  generation_gwh_2018
# 9    1.100895      Power_plant_age

# %% [markdown]
# The VIF value is less than 10 in all the columns which means we have no multicollinearity problem.

# %%
x1.head()
# Out:
#    longitude  primary_fuel    source  geolocation_source  generation_gwh_2014  \
# 0  -0.922017      1.175506  1.397951           -1.036523            -0.021192
# 1  -0.499918     -0.975797  2.821796            0.407145            -0.021192
# 2  -2.377242      1.605767 -0.529717            0.407145            -0.021192
# 3   2.431133     -0.545536 -0.507812            0.407145            -0.249076
# 4   1.262067     -0.975797 -0.507812            0.407145             1.402492
#
#    generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0            -0.028353            -0.025970            -0.017684
# 1            -0.028353            -0.025970            -0.017684
# 2            -0.028353            -0.025970            -0.017684
# 3             0.114643             0.125811            -0.183330
# 4             2.209237             2.202688             1.935643
#
#    generation_gwh_2018  Power_plant_age
# 0            -0.037438        -1.109091
# ...

# %% [markdown]
# # Finding best random state:-

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x1_train,x1_test,y1_train,y1_test = train_test_split(x1,y1,test_size=.30, random_state=i)
    mod = RandomForestRegressor()
    mod.fit(x1_train, y1_train)
    pred = mod.predict(x1_test)
    acc=r2_score(y1_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum r2 score is ",maxAccu," on Random_state ",maxRS)
# Out:
# Maximum r2 score is  0.8659594554326504  on Random_state  185

# %% [markdown]
# # Creating train test split:-

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=.30,random_state=maxRS)

# %% [markdown]
# # Regression Algorithms:-

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %% [markdown]
# # Random Forest Regressor:-

# %%
RFR=RandomForestRegressor()
RFR.fit(x1_train,y1_train)

# prediction
predRFR=RFR.predict(x1_test)
print('R2_Score:',r2_score(y1_test,predRFR))
print('MAE:',metrics.mean_absolute_error(y1_test, predRFR))
print('MSE:',metrics.mean_squared_error(y1_test, predRFR))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y1_test, predRFR)))
# Out:
# R2_Score: 0.8576950620492126
# MAE: 84.15578375108822
# MSE: 26884.984467905822
# RMSE: 163.9664126213226

# %% [markdown]
# # Decision Tree Regressor:-

# %%
DTR=DecisionTreeRegressor()
DTR.fit(x1_train,y1_train)

# prediction
predDTR=DTR.predict(x1_test)
print('R2_Score:',r2_score(y1_test,predDTR))
print('MAE:',metrics.mean_absolute_error(y1_test, predDTR))
print('MSE:',metrics.mean_squared_error(y1_test, predDTR))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y1_test, predDTR)))
# Out:
# R2_Score: 0.6612096196345115
# MAE: 119.305958984375
# MSE: 64006.029904260744
# RMSE: 252.99413017748208

# %% [markdown]
# # KNeighbors Regressor:-

# %%
knn=KNN()
knn.fit(x1_train,y1_train)

# prediction
predknn=knn.predict(x1_test)
print('R2_Score:',r2_score(y1_test,predknn))
print('MAE:',metrics.mean_absolute_error(y1_test, predknn))
print('MSE:',metrics.mean_squared_error(y1_test, predknn))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y1_test, predknn)))
# Out:
# R2_Score: 0.7924426738774414
# MAE: 103.79490625
# MSE: 39212.80293825656
# RMSE: 198.0222283943309

# %% [markdown]
# # GradientBoosting Regressor:-

# %%
GB=GradientBoostingRegressor()
GB.fit(x1_train,y1_train)

# prediction
predGB=GB.predict(x1_test)
print('R2_Score:',r2_score(y1_test,predGB))
print('MAE:',metrics.mean_absolute_error(y1_test, predGB))
print('MSE:',metrics.mean_squared_error(y1_test, predGB))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y1_test, predGB)))
# Out:
# R2_Score: 0.8504101215205742
# MAE: 90.30264396604741
# MSE: 28261.29308925385
# RMSE: 168.11095469734818

# %% [markdown]
# # BaggingRegressor:-

# %%
BR=BaggingRegressor()
BR.fit(x1_train,y1_train)

# prediction
predBR=BR.predict(x1_test)
print('R2_Score:',r2_score(y1_test,predBR))
print('MAE:',metrics.mean_absolute_error(y1_test, predBR))
print('MSE:',metrics.mean_squared_error(y1_test, predBR))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y1_test, predBR)))
# Out:
# R2_Score: 0.8720146813100438
# MAE: 80.82012436316938
# MSE: 24179.647977425724
# RMSE: 155.4980642240466

# %% [markdown]
# # Checking the cross validation score:-

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(RFR,x1,y1,cv=5).mean())   #random forest
# Out:
# 0.7786150014081625

# %%
print(cross_val_score(DTR,x1,y1,cv=5).mean())     #decision tree
# Out:
# 0.5682493630885519

# %%
print(cross_val_score(knn,x1,y1,cv=5).mean())      #knn
# Out:
# 0.7227367589867385

# %%
print(cross_val_score(GB,x1,y1,cv=5).mean())      #gradient boosting
# Out:
# 0.750495420877065

# %%
print(cross_val_score(BR,x1,y1,cv=5).mean())       #bagging regressor
# Out:
# 0.780562932552123

# %% [markdown]
# From the above observation, the difference between R2 score and the cross validation score we conclude that KNeighbors is our best fitting model.

# %% [markdown]
# # Hyper parameter tuning:-

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'n_neighbors':[2,3,4,5,6],                                #knn
             'algorithm':['auto','ball_tree','kd_tree','brute'],
             'leaf_size':[10,20,30,40,50],
             'weights':['uniform','distance']}

# %%
GCV=GridSearchCV(KNN(),parameters,cv=5)

# %%
GCV
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(),
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'leaf_size': [10, 20, 30, 40, 50],
#                          'n_neighbors': [2, 3, 4, 5, 6],
#                          'weights': ['uniform', 'distance']})

# %%
GCV.fit(x1_train,y1_train)
GCV.best_params_
# Out:
# {'algorithm': 'brute',
#  'leaf_size': 10,
#  'n_neighbors': 6,
#  'weights': 'distance'}

# %%
capacity = KNN(algorithm='brute', leaf_size=10, n_neighbors=6, weights='distance')
capacity.fit(x1_train, y1_train)
pred = capacity.predict(x1_test)
print("RMSE value:",np.sqrt(metrics.mean_squared_error(y1_test, predRFR)))
print('R2_Score:',r2_score(y1_test,pred)*100)
# Out:
# RMSE value: 163.9664126213226
# R2_Score: 79.44924729836941

# %% [markdown]
# After tuning the model we got r2_score=79.44%.

# %% [markdown]
# # Saving the model:-

# %%
import joblib
joblib.dump(capacity,"Global_PowerPlant_capacity_mw.pkl")
# Out:
# ['Global_PowerPlant_capacity_mw.pkl']
